# %% [markdown]
# # Auswertung des Füllverhalten von Glas-Sammelstellen
#
# Dominik Gschwind, Cedric Christen, Roman Weiss, Roméo Bornand

# %% [markdown]
# ## Agenda
#
# - Beziehung zwischen Bevölkerungsdichte und Füllverhalten
# - Untersuchung der Füllmessdaten
# - Vorhersagen mit linearem Modell
# - Ausblick

# %% [markdown]
# # Beziehung zwischen Bevölkerungsdichte und Füllverhalten

# %% [markdown]
# ![](../img/people_alloc_stations.png)

# %% [markdown]
# <div style="display: flex; flex-flow: row nowrap; align-items: center;">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# </div>

# %% [markdown]
# # Untersuchung der Füllmessdaten

# %% [markdown]
# - Verbesserung der Daten: Peaks entfernen

# %% [markdown]
# ![](../img/raw_data.png)

# %% [markdown]
# - Zuschneiden in Perioden zwischen Entleerungen

# %% [markdown]
# ![](../img/period_data.png)

# %% [markdown]
# ## Vorhersagen mit linearem Modell

# %% [markdown]
# ```
# 104244: RSE=1.27382, R_Sq=0.76553, MSE=0.00901, slope=0.07693
# 104250: RSE=3.26027, R_Sq=0.46399, MSE=0.00510, slope=0.02680
# 107040 | 8572: RSE=3.49779, R_Sq=0.60557, MSE=0.00256, slope=0.03814
# 107047 | 0D1A: RSE=1.05235, R_Sq=0.84285, MSE=0.33618, slope=0.04954
# 107049 | 4B00: RSE=1.77036, R_Sq=0.65097, MSE=0.00933, slope=0.04304
# 107058 | 282C: RSE=1.73083, R_Sq=0.86124, MSE=0.00264, slope=0.02757
# 107062 | 49A3: RSE=1.71286, R_Sq=0.33551, MSE=0.00475, slope=0.06217
# 107064 | 4B16: RSE=1.55258, R_Sq=0.48711, MSE=0.00481, slope=0.06763
# 107065 | 4A3D: RSE=1.46092, R_Sq=0.88596, MSE=0.00397, slope=0.04395
# 107066 | 0F09: RSE=1.05340, R_Sq=0.94234, MSE=0.00278, slope=0.03369
# 107072 | F389: RSE=0.72989, R_Sq=0.85299, MSE=0.00622, slope=0.05800
# 107075 | 2B2A: RSE=2.98741, R_Sq=0.35012, MSE=0.00650, slope=0.01713
# 107095 | 64BC: RSE=1.24480, R_Sq=0.00831, MSE=0.00622, slope=0.12240
# 107098 | 0DE6: RSE=1.06914, R_Sq=0.86901, MSE=0.00196, slope=0.03257
# 107113 | F502: RSE=0.82663, R_Sq=0.85387, MSE=0.00288, slope=0.05512
# 107115 | 7F12: RSE=27.99505, R_Sq=-145.02599, MSE=0.00245, slope=0.06266
# 107121 | 679F: RSE=6.13556, R_Sq=-1.35497, MSE=0.00344, slope=0.02039
# 107124 | 2503: RSE=0.65883, R_Sq=0.86205, MSE=0.00614, slope=0.10969
# 107129 | 4AE2: RSE=0.42806, R_Sq=0.95673, MSE=0.00269, slope=0.12189
# 104245: RSE=64.28182, R_Sq=0.00000, MSE=0.18363, slope=0.01046
# 104252: RSE=2.13334, R_Sq=-0.94722, MSE=0.00830, slope=0.02093
# 107026 | 67BE: RSE=2.71282, R_Sq=0.72932, MSE=0.00365, slope=0.02593
# 107028 | 4B8D: RSE=5.13864, R_Sq=0.43831, MSE=0.03390, slope=0.01495
# 107043 | 8300: RSE=5.43700, R_Sq=0.43284, MSE=0.00349, slope=0.01770
# 107044 | 63DB: RSE=2.50691, R_Sq=0.80837, MSE=0.01122, slope=0.02244
# 107053 | 667E: RSE=2.30262, R_Sq=0.88287, MSE=0.00471, slope=0.02659
# 107054 | 2AE2: RSE=2.74778, R_Sq=0.70114, MSE=0.00545, slope=0.03768
# 107057 | 69C8: RSE=1.81349, R_Sq=0.87984, MSE=0.00377, slope=0.03913
# 107063 | 45A5: RSE=1.81830, R_Sq=0.91762, MSE=0.00439, slope=0.02417
# 107097 | 0C5C: RSE=0.81039, R_Sq=0.91368, MSE=0.00365, slope=0.05758
# 107104 | 66E0: RSE=2.28584, R_Sq=0.89203, MSE=0.00374, slope=0.02782
# 107109 | 67EF: RSE=2.68381, R_Sq=0.84571, MSE=0.00557, slope=0.01470
# 107128 | 0BCE: RSE=14.16192, R_Sq=-5.48545, MSE=0.00331, slope=0.03263
# 107130 | 4818: RSE=160.58488, R_Sq=-12465.65534, MSE=0.00257, slope=0.03268
# 104243: RSE=135.39855, R_Sq=-4001.80170, MSE=2.68073, slope=0.04571
# 104246: RSE=133.94989, R_Sq=0.00000, MSE=0.01547, slope=0.02444
# 107029 | 6436: RSE=2.15002, R_Sq=0.39459, MSE=0.00358, slope=0.08028
# 107031 | 6348: RSE=2.33557, R_Sq=0.57800, MSE=0.00749, slope=0.02604
# 107034 | 8104: RSE=2.19629, R_Sq=0.17250, MSE=0.01545, slope=0.05544
# 107036 | 2AA8: RSE=4.14442, R_Sq=0.78630, MSE=0.00314, slope=0.01181
# 107038 | 2B8D: RSE=2.50774, R_Sq=0.55469, MSE=0.01007, slope=0.03485
# 107041 | 470A: RSE=1.92006, R_Sq=0.15675, MSE=0.00568, slope=0.05373
# 107048 | 671B: RSE=1.56672, R_Sq=0.88210, MSE=0.00521, slope=0.04911
# 107055 | 2C76: RSE=1.55721, R_Sq=0.85070, MSE=0.00623, slope=0.04526
# 107067 | 84A1: RSE=2.09303, R_Sq=0.88374, MSE=0.00276, slope=0.01896
# 107068 | 4455: RSE=2.48623, R_Sq=-0.20816, MSE=0.00310, slope=0.03640
# 107077 | 2CC4: RSE=26.46280, R_Sq=-59.69054, MSE=1.40965, slope=0.03409
# 107096 | 4814: RSE=0.50157, R_Sq=0.80948, MSE=0.01898, slope=0.19809
# 107108 | 0AEA: RSE=329.11850, R_Sq=-57423.91082, MSE=0.00372, slope=0.06588
# ```

# %% [markdown]
# <div style="overflow: auto; max-width: 90%; max-height: 80%;">
# <img src="../img/weissglas.png"></img>
# </div>

# %% [markdown]
# <div style="overflow: auto; max-width: 90%; max-height: 80%;">
# <img src="../img/braunglas.png"></img>
# </div>

# %% [markdown]
# <div style="overflow: auto; max-width: 90%; max-height: 80%;">
# <img src="../img/grünglas.png"></img>
# </div>

# %% [markdown]
# ## Ausblick
#
# - Andere Einflüsse ausser Füllstand nicht beachtet (z.B. Feiertage, Wetter, ...)
# - Füllstand: 0% ist maximale Sensordistanz, 100% ist minimale Sensordistanz
# - Daten sind bei manchen Sensoren bedürftig
#     - Wenig Daten, Fehlerhaft, Tendenz wechselt Sprunghaft

# %% [markdown]
# # Vielen Dank für die Aufmerksamkeit
