# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
quartier_counts = pd.read_csv("C:/Users/n3xed/OneDrive - OST/Hackathon 2023/Bevölkerungsdaten nach Quartier.csv", sep=";")
quartier_counts = quartier_counts[["GEBIET_NAME", "INDIKATOR_JAHR", "INDIKATOR_VALUE"]]

quartier_counts
# Out:
#                                 GEBIET_NAME  INDIKATOR_JAHR  INDIKATOR_VALUE
# 0                    Quartiergruppe Winkeln            2020             4510
# 1                    Quartiergruppe Winkeln            2021             4493
# 2                    Quartiergruppe Winkeln            2022             4577
# 3                    Quartiergruppe Bruggen            2020            13099
# 4                    Quartiergruppe Bruggen            2021            13162
# ..                                      ...             ...              ...
# 130                  Quartier Achslen-Wilen            2021             4430
# 131                  Quartier Achslen-Wilen            2022             4612
# 132  Quartier Stephanshorn-Zil-Kesselhalden            2020             4106
# 133  Quartier Stephanshorn-Zil-Kesselhalden            2021             4080
# 134  Quartier Stephanshorn-Zil-Kesselhalden            2022             4125
#
# [135 rows x 3 columns]

# %%
quartier_counts = quartier_counts[quartier_counts["GEBIET_NAME"].str.contains("Quartier ")]

print(quartier_counts["GEBIET_NAME"].unique())
print(len(quartier_counts["GEBIET_NAME"].unique()))
# Out:
# ['Quartier Hafnersberg' 'Quartier Breitfeld-Gründenmoos'
#  'Quartier Winkeln Nord-Industrie' 'Quartier Winkeln Süd'
#  'Quartier Gübsensee' 'Quartier Chräzeren' 'Quartier Altenwegen'
#  'Quartier Sittertobel' 'Quartier Bruggen-Zürcherstrasse'
#  'Quartier Boppartshof-Hinterberg' 'Quartier Haggen-Oberstrasse-Langweid'
#  'Quartier Moos-Waldacker-Lerchenfeld' 'Quartier Vonwil-Lachen-Schoren'
#  'Quartier Hölzli-Joosrüti' 'Quartier Rosenberg-Kreuzbleiche'
#  'Quartier Riethüsli' 'Quartier St.Georgen-Bernegg'
#  'Quartier St.Leonhard-Ost' 'Quartier Altstadt' 'Quartier St.Jakob'
#  'Quartier Linsebühl-Dreilinden' 'Quartier St.Georgen-Bach'
#  'Quartier Stuelegg-Rüti' 'Quartier Rotmonten'
#  'Quartier Langgass-Heiligkreuz' 'Quartier St.Fiden-Krontal'
#  'Quartier Notkersegg' 'Quartier Kurzegg-Rank'
#  'Quartier Hub-Schaugentobel' 'Quartier Achslen-Wilen'
#  'Quartier Stephanshorn-Zil-Kesselhalden']
# 31

# %%
import geopandas as gpd
import geoplot

# %%
district_map = gpd.read_file("C:/Users/n3xed/OneDrive - OST/Hackathon 2023/wohnviertel.geojson")
district_map.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
geoplot.polyplot(district_map, projection=geoplot.crs.AlbersEqualArea(), edgecolor='darkgrey', facecolor='lightgrey', linewidth=.3, figsize=(12, 8))
# Out:
# <GeoAxes: >
